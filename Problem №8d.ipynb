# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
a=1
b=1
c=1
h=0.00
x = np.linspace(0, 5, 3000)
tt = 30.0
plt.plot(x, (h-b*x*x*x+3.0*c*x*x)/(a*x)+tt)
plt.plot([0.0, 6.0], [30.0, 30.0])
# Out:
# /home/nick/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
plt.grid()
h=0.5
c=1
x = np.linspace(0, 2, 3000)
plt.plot([0.0, 2.0], [0.0,0.0])
plt.plot(x, (-h-2*b*x*x*x+3.0*c*x*x))
